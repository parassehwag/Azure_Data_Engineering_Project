# %%
{
  "name": "Weekday Runs",
  "email_notifications": {
    "no_alert_for_skipped_runs": false
  },
  "webhook_notifications": {},
  "timeout_seconds": 0,
  "max_concurrent_runs": 1,
  "tasks": [
    {
      "task_key": "WeekdayLookup",
      "run_if": "ALL_SUCCESS",
      "notebook_task": {
        "notebook_path": "/Workspace/Netflix_Project/5_lookupNotebook",
        "base_parameters": {
          "weekday": "{{job.start_time.iso_weekday}}"
        },
        "source": "WORKSPACE"
      },
      "existing_cluster_id": "0726-110223-hw0h6ik8",
      "timeout_seconds": 0,
      "email_notifications": {},
      "webhook_notifications": {}
    },
    {
      "task_key": "IfWeekday",
      "depends_on": [
        {
          "task_key": "WeekdayLookup"
        }
      ],
      "run_if": "ALL_SUCCESS",
      "condition_task": {
        "op": "EQUAL_TO",
        "left": "{{tasks.WeekdayLookup.values.week_output}}",
        "right": "7"
      },
      "timeout_seconds": 0,
      "email_notifications": {},
      "webhook_notifications": {}
    },
    {
      "task_key": "FalseNotebook",
      "depends_on": [
        {
          "task_key": "IfWeekday",
          "outcome": "true"
        }
      ],
      "run_if": "ALL_SUCCESS",
      "notebook_task": {
        "notebook_path": "/Workspace/Netflix_Project/6-testWorkflow",
        "source": "WORKSPACE"
      },
      "existing_cluster_id": "0726-110223-hw0h6ik8",
      "timeout_seconds": 0,
      "email_notifications": {},
      "webhook_notifications": {}
    },
    {
      "task_key": "silverMasterData",
      "depends_on": [
        {
          "task_key": "IfWeekday",
          "outcome": "false"
        }
      ],
      "run_if": "ALL_SUCCESS",
      "notebook_task": {
        "notebook_path": "/Workspace/Netflix_Project/4_Silver",
        "source": "WORKSPACE"
      },
      "existing_cluster_id": "0726-110223-hw0h6ik8",
      "timeout_seconds": 0,
      "email_notifications": {},
      "webhook_notifications": {}
    }
  ],
  "queue": {
    "enabled": true
  },
  "performance_target": "STANDARD",
  "run_as": {
    "user_name": "parassehwag@outlook.com"
  }
}
